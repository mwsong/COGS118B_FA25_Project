# %%
from mushroom import *

# %% [markdown]
# Lastly, we test PCA and K-Means clustering with embedding images and text descriptions of the different species. We test this with 1. just 2 mushrooms that look evidently different. 2. just 2 mushrooms that look very similar (one poisonous, one not)
# 3.. etc.

# %%
#can change and edit later too, and indices on right
DESCRIPTIVE_LABELS = [
    "a bright red mushroom with a white stem found under beech trees", #0
    "a red, juicy fungus that looks like raw beef", #1
    "a golden yellow trumpet-shaped mushroom with wavy edges", #2
    "a brown poisonous mushroom with a web-like veil", #3
    "a deadly white mushroom with a smooth cap and volva", #4
    "a pure white toxic mushroom with a bulbous base", #5
    "a common white edible mushroom with pink gills", #6
    "a red cap mushroom with white spots, toxic but iconic", #7
    "a small brown poisonous mushroom growing on wood", #8
    "a tuft of orange-brown mushrooms found on decaying wood" #9
]
